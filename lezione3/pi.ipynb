# %%
import random

class Point:
    def __init__(self, x, y):
        self.x = x
        self.y = y
    
    def distance(self, other):
        return ((self.x - other.x)**2 + (self.y - other.y)**2)**0.5

    def distance_origin(self):
        origin = Point(0, 0)
        return self.distance(origin)

    def is_inside_unit_circle(self):
        if self.distance_origin() <= 1:
            return True
        return False

# %%
import math
points_inside = 0
points_tot = 2000000

for i in range(0, points_tot):
    x = random.uniform(-1, 1)
    y = random.uniform(-1, 1)
    p = Point(x, y)
    is_inside = p.is_inside_unit_circle()
    if is_inside:
        points_inside = points_inside + 1

pi = points_inside / points_tot * 4
print("il valore stimato di pi è:", pi)

error = abs(pi - math.pi)
error_percentage = error / math.pi * 100

print("l'errore percentuale è", error_percentage, "%")
# Out:
# il valore stimato di pi è: 3.140674
# l'errore percentuale è 0.02924165196093177 %

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(-5, 5, 2000)
y = x ** 2

plt.plot(x, y)
plt.title("parabola")
plt.xlabel("x")
plt.ylabel("y")
# Out:
# Text(0, 0.5, 'y')
